# %% [markdown]
# # Temporal Logic Monitoring in Python
#
# RTAMT is a Python library for monitoring Signal Temporal Logic (STL). It supports both offline and online monitoring of discrete-time and dense-time STL specifications.
#
# For more details, refer to the [RTAMT GitHub repository](https://github.com/nickovic/rtamt).
#
# ## Installation
#
# Install the following package for RTAMT:

# %%
# %pip install rtamt

# %% [markdown]
# ## Usage
#
# RTAMT can be used in four ways:
# - **discrete-time** (discrete time-steps) versus **dense-time** (continuous signals), and
# - **online** (signal values are added one-at-a-time) versus **offline** (the entire trace is available)
#
# ---
#
# ### Discrete-Time Online Monitor
#
# The `StlDiscreteTimeSpecification` class is used for monitoring discrete-time STL specifications. Here is an example that checks whether `a >= b` eventually holds within a window of 1 time-step:

# %%
import sys
import rtamt

def monitor():
    # create the STL specification
    spec = rtamt.StlDiscreteTimeSpecification()
    spec.declare_var('a', 'int')
    spec.declare_var('b', 'int')
    spec.spec = 'eventually[0,1] (a >= b)'

    # parse the specification
    try:
        spec.parse()
        spec.pastify()
    except rtamt.RTAMTException as err:
        print('RTAMT Exception: {}'.format(err))
        sys.exit()

    # feed signal values one time-step at a time
    for t, a_val, b_val in [(0, 100, 20), (1, 10, 20), (2, 1, 20), (3, 2, 1)]:
        robustness = spec.update(t, [('a', a_val), ('b', b_val)])
        print(f'time={t}  robustness={robustness}')

monitor()

# %% [markdown]
# ---
#
# ### Discrete-Time Offline Monitor — Incubator Data
#
# We can also evaluate specifications over a complete pre-recorded trace by iterating through it sample by sample. Here, we load a CSV dataset from the incubator digital twin and monitor two properties using an online-style monitor over this offline dataset.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Load the incubator dataset
current_dir = os.getcwd()
assert os.path.basename(current_dir) == '8-Monitoring', 'Current directory is not 8-Monitoring'

parent_dir = os.path.dirname(current_dir)
assert os.path.exists(os.path.join(parent_dir, 'incubator_dt')), 'incubator_dt folder not found in the repository root'

csv_file_path = os.path.join(parent_dir, 'incubator_dt', 'software', 'incubator', 'datasets',
                             '20230501_calibration_empty_system', '20230501_calibration_empty_system.csv')
assert os.path.exists(csv_file_path), 'CSV file not found in the incubator repository.'

data = pd.read_csv(csv_file_path)
data.head()

# %% [markdown]
# #### Specification 1: Checking incubator temperature
#
# Does the incubator temperature eventually reach 37°C within a 20-step window?

# %%
import sys
import rtamt

def monitor_spec(spec_str, variables):
    """Run a discrete-time online monitor over the incubator dataset.
    
    Args:
        spec_str: The STL specification string.
        variables: List of (name, type, io_type) tuples for the signal variables.
    
    Returns:
        robustness: List of robustness values per time-step.
        first_moment: First time-step where the property is satisfied (-1 if never).
    """
    spec = rtamt.StlDiscreteTimeSpecification(semantics=rtamt.Semantics.STANDARD)
    for name, dtype, io_type in variables:
        spec.declare_var(name, dtype)
        spec.set_var_io_type(name, io_type)
    spec.spec = spec_str

    try:
        spec.parse()
        spec.pastify()
    except rtamt.RTAMTException as err:
        print('RTAMT Exception: {}'.format(err))
        sys.exit()

    first_moment = -1
    robustness = []
    n = len(data)
    var_names = [v[0] for v in variables]
    for i in range(n):
        rob = spec.update(i, [(name, data[name].iloc[i]) for name in var_names])
        robustness.append(rob)
        if rob > 0 and first_moment == -1:
            first_moment = i

    return robustness, first_moment

robustness1, first_moment1 = monitor_spec(
    'eventually[0:20](average_temperature >= 37)',
    [('average_temperature', 'float', 'output')]
)
print(f'Satisfied at time-step: {first_moment1}')

# %%
plt.figure(figsize=(10, 4))
plt.plot(data.index, data.average_temperature, label='Temperature')
plt.plot(data.index, robustness1, label='Robustness')
plt.axhline(y=37, color='r', linestyle='--', label='Threshold (37°C)')
plt.axhline(y=0, color='black', linestyle='-', alpha=0.3)
if first_moment1 >= 0:
    plt.axvline(x=first_moment1, color='g', linestyle='-', label=f'First satisfied (t={first_moment1})')
plt.ylabel('Temperature (°C) / Robustness')
plt.xlabel('Time-step')
plt.title('Spec 1: Eventually temperature ≥ 37°C')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Specification 2: Temperature response after heater activation
#
# If the heater is on, does the temperature reach 35°C within 5 time-steps?

# %%
robustness2, first_moment2 = monitor_spec(
    '((heater_on == 1) implies eventually[0:5] (average_temperature >= 35))',
    [('average_temperature', 'float', 'output'),
     ('heater_on', 'float', 'input')]
)
print(f'Satisfied at time-step: {first_moment2}')

# %%
plt.figure(figsize=(10, 4))
plt.plot(data.index, data.average_temperature, label='Temperature')
plt.plot(data.index, data.heater_on * 10, label='Heater On (×10)', alpha=0.5)
plt.plot(data.index, robustness2, label='Robustness')
plt.axhline(y=35, color='r', linestyle='--', label='Threshold (35°C)')
plt.axhline(y=0, color='black', linestyle='-', alpha=0.3)
if first_moment2 >= 0:
    plt.axvline(x=first_moment2, color='g', linestyle='-', label=f'First satisfied (t={first_moment2})')
plt.ylabel('Temperature (°C) / Robustness')
plt.xlabel('Time-step')
plt.title('Spec 2: Heater on → eventually temperature ≥ 35°C')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### Dense-Time Monitoring
#
# RTAMT also supports dense-time (continuous) signals.
#
# #### Offline dense-time monitoring
#
# Signal values are provided as lists of `[timestamp, value]` pairs. The specification is evaluated over the entire trace (example from the [RTAMT paper](https://link.springer.com/article/10.1007/s10009-023-00720-3)):

# %%
import rtamt

# Signals as lists of [timestamp, value]
req = [[0.0, 0.0], [3.0, 6.0], [5.0, 0.0]]
gnt = [[0.0, 0.0], [7.0, 6.0], [9.0, 0.0]]

spec = rtamt.StlDenseTimeSpecification()
spec.declare_var('req', 'float')
spec.declare_var('gnt', 'float')
spec.spec = 'always((req >= 3) implies (eventually[0:5](gnt >= 3)))'
spec.parse()

rob = spec.evaluate(['req', req], ['gnt', gnt])
print('Robustness:', rob)

# %% [markdown]
# Note that the output format is `[[timestamp, robustness]]` — RTAMT computes _quantitative_ (robustness) semantics, where positive values mean the property is satisfied and negative values mean it is violated.
#
# #### Online dense-time monitoring
#
# RTAMT also supports online monitoring, where signal values arrive in chunks. The `update` method accepts partial signal segments and returns robustness values incrementally:

# %%
import sys
import rtamt

def online_monitor():
    # Three chunks of signal data arriving over time
    a1 = [(0, 3), (3, 2)]
    b1 = [(0, 2), (2, 5), (4, 1), (7, -7)]

    a2 = [(5, 6), (6, -2), (8, 7), (11, -1)]
    b2 = [(10, 4)]

    a3 = [(13, -6), (15, 0)]
    b3 = [(15, 0)]

    spec = rtamt.StlDenseTimeSpecification()
    spec.name = 'STL dense-time online'
    spec.declare_var('a', 'float')
    spec.spec = 'a >= 2'
    try:
        spec.parse()
    except rtamt.RTAMTException as err:
        print('RTAMT Exception: {}'.format(err))
        sys.exit()

    # Feed chunks of data incrementally
    for chunk_a, chunk_b in [(a1, b1), (a2, b2), (a3, b3)]:
        rob = spec.update(['a', chunk_a], ['b', chunk_b])
        print('rob:', rob)

online_monitor()

# %% [markdown]
# For more details, refer to the [RTAMT GitHub repository](https://github.com/nickovic/rtamt).
#
# ---
#
# ## Exercises
#
# ### Exercise 1: Understanding STL specifications
#
# 1. What do the two incubator specifications (Spec 1 and Spec 2) mean in **natural language**? How would you explain them to someone unfamiliar with temporal logic?
# 2. The second plot shows that the robustness is 0 near the beginning of the trace. In quantitative semantics, 0 is the boundary between satisfaction (>0) and violation (<0), rather than a clear pass or fail. Why does the robustness become 0 there, and how would you interpret this borderline case?
#
# ### Exercise 2: Quantitative vs. Boolean Semantics
#
# Can you convert the output from the dense-time `spec.evaluate()` into boolean verdicts? (i.e., an array of form `[[float, bool]]`)
#
# Compare this to the quantitative results. Which representation gives you more information?
#
# ### Exercise 3: Online monitoring for Digital Twins
#
# The online `update()` method allows monitors to handle progressively arriving data.
#
# How could you use this to monitor data received from a network connection or a time-series database in a Digital Twin context?
#
# ### Exercise 4: Experimenting with specifications
#
# Experiment with the incubator specifications above. Try changing the temporal operator (`eventually` → `always`), the time bounds, or the threshold values.
#
# Report **three** experiments by:
# - Writing the specification you chose
# - Showing the resulting plot
# - Describing what the plot shows and how it relates to the specification
